# %% [markdown]
# ## Importing Data from online source

# %%
#import necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt


#read & extract data from url - https://flightaware.com/live/airport/KJFK 
#flight details of aircrafts coming in & out of JFK International Airport is considered
jfk = pd.read_html('https://flightaware.com/live/airport/KJFK')
#jfk

#concatenate arrival, departure, enroute & scheduled flight departure tables into a single pandas df  
jfk = pd.concat(jfk, axis=1, ignore_index=False)
jfk
# Out:
#    (Arrivals (More), Ident) (Arrivals (More), Type)  \
# 0                   ICV5523                    B748
# 1                   JBU2492                    A320
# 2                    DAL442                    B763
# 3                   DAL2245                    B739
# 4                    DAL436                    B764
# 5                    CMP804                    B738
# 6                   AAL2201                    A321
# 7                   ABX3162                    B762
# 8                   JBU2126                    A320
# 9                    JBU284                    A321
# 10                  JBU1202                    A320
# 11                  DAL2238                    A321
# 12                  AAL1357                    B738
# 13                  JBU1882                    E190
# 14                  EDV5499                    CRJ9
# 15                   DAL517                    B739
# 16                   JBU342                    E190
# 17                   JBU694                    A320
# 18                  JBU2928                    A321
# 19                  ATN3332                    B763
#
#             (Arrivals (More), From) (Arrivals (More), Depart)  \
# 0         Chicago O'Hare Intl (ORD)                09:37p CDT
# 1                  Miami Intl (MIA)                09:43p EDT
# 2         San Francisco Int'l (SFO)                04:24p PDT
# 3             Harry Reid Intl (LAS)                04:45p PDT
# 4            Los Angeles Intl (LAX)                04:27p PDT
# 5               Tocumen Int'l (PTY)                06:31p EST
# 6            Los Angeles Intl (LAX)                04:15p PDT
# 7         San Bernardino Intl (SBD)                04:34p PDT
# 8                  Tampa Intl (TPA)                09:41p EDT
# 9                Orlando Intl (MCO)                09:36p EDT
# 10       Fort Lauderdale Intl (FLL)                09:26p EDT
# 11                 Miami Intl (MIA)                09:07p EDT
# 12                 Miami Intl (MIA)                09:02p EDT
# 13       Houston Bush Int'ctl (IAH)                07:26p CDT
# 14   Minneapolis/St Paul Intl (MSP)                08:19p CDT
# 15    Hartsfield-Jackson Intl (ATL)                09:39p EDT
# 16  Savannah/Hilton Head Intl (SAV)                09:47p EDT
# 17      Austin-Bergstrom Intl (AUS)                07:07p CDT
# 18               Orlando Intl (MCO)                09:03p EDT
# 19        Fort Worth Alliance (AFW)                07:15p CDT
#
#     (Arrivals (More), Unnamed: 4_level_1) (Arrivals (More), Arrive)  \
# 0                                     NaN                12:10a EDT
# 1                                     NaN                12:09a EDT
# 2                                     NaN                12:07a EDT
# 3                                     NaN                12:05a EDT
# 4                                     NaN                12:00a EDT
# 5                                     NaN                12:00a EDT
# 6                                     NaN                12:00a EDT
# 7                                     NaN                11:58p EDT
# 8                                     NaN                11:56p EDT
# 9                                     NaN                11:47p EDT
# 10                                    NaN                11:47p EDT
# 11                                    NaN                11:33p EDT
# 12                                    NaN                11:32p EDT
# 13                                    NaN                11:31p EDT
# 14                                    NaN                11:29p EDT
# 15                                    NaN                11:29p EDT
# 16                                    NaN                11:26p EDT
# 17                                    NaN                11:22p EDT
# 18                                    NaN                11:16p EDT
# 19                                    NaN                11:15p EDT
#
#    (Departures (More), Ident) (Departures (More), Type)  \
# 0                        ELY8                      B788
# 1                      DAL234                      A339
# 2                     JBU1523                      A321
# 3                      JBU745                      A320
# 4                     RPA5836                      E170
# 5                      ABX152                      B763
# 6                     LPE2381                      B763
# 7                      UAE202                      A388
# 8                      JBU234                      E190
# 9                     CAL5321                      B744
# 10                     JBU553                      A320
# 11                     BAW182                      B77W
# 12                     JBU553                      A320
# 13                     VIR138                      B789
# 14                      AFR17                      B772
# 15                    UPS1111                      MD11
# 16                    GEC8163                      B77L
# 17                    FDX1612                      MD11
# 18                     DAL471                      B763
# 19                     JBU676                      E190
#
#                               (Departures (More), To)  \
# 0                              Ben Gurion Int'l (TLV)
# 1                              Ben Gurion Int'l (TLV)
# 2                              Los Angeles Intl (LAX)
# 3                                     Mercedita (PSE)
# 4                             Boston Logan Intl (BOS)
# 5   Cincinnati/Northern Kentucky International Air...
# 6                            Jorge Chávez Int'l (LIM)
# 7                                   Dubai Int'l (DXB)
# 8                               Burlington Intl (BTV)
# 9                                Anchorage Intl (ANC)
# 10                                                NaN
# 11                              London Heathrow (LHR)
# 12                              Palm Beach Intl (PBI)
# 13                              London Heathrow (LHR)
# 14                     Charles de Gaulle/Roissy (CDG)
# 15                            Muhammad Ali Intl (SDF)
# 16                              Frankfurt Int'l (FRA)
# 17                            Indianapolis Intl (IND)
# 18                    São Paulo-Guarulhos Int'l (GRU)
# 19                               Worcester Rgnl (ORH)
#
#    (Departures (More), Depart)  ...  \
# 0                   12:06a EDT  ...
# 1                   12:04a EDT  ...
# 2                   11:59p EDT  ...
# 3                   11:44p EDT  ...
# 4                   11:33p EDT  ...
# 5                   11:31p EDT  ...
# 6                   11:30p EDT  ...
# 7                   11:26p EDT  ...
# 8                   11:25p EDT  ...
# 9                   11:24p EDT  ...
# 10                  11:23p EDT  ...
# 11                  11:20p EDT  ...
# 12                  11:19p EDT  ...
# 13                  11:17p EDT  ...
# 14                  11:13p EDT  ...
# 15                  11:12p EDT  ...
# 16                  11:11p EDT  ...
# 17                  11:09p EDT  ...
# 18                  11:07p EDT  ...
# 19                  11:06p EDT  ...
#
#     (En Route/Scheduled to JFK (More), Depart)  \
# 0                                   10:15p EDT
# 1                                   08:45p AST
# 2                                   07:05p EST
# 3                                   07:17p CDT
# 4                                   10:06p EDT
# 5                                   10:28p EDT
# 6                                   07:26p MDT
# 7                                   08:17p AST
# 8                                   05:21p PDT
# 9                                   06:55p CST
# 10                                  04:30p MDT
# 11                                  07:06p CST
# 12                                  10:00p BST
# 13                                  07:29p CST
# 14                                  07:25p CST
# 15                                  09:47p EST
# 16                                  11:00p AST
# 17                                 12:34a CEST
# 18                                  09:32p EST
# 19                                  09:32p -05
#
#    (En Route/Scheduled to JFK (More), Unnamed: 4_level_1)  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
#
#    (En Route/Scheduled to JFK (More), Arrive)  \
# 0                                  12:14a EDT
# 1                                  12:20a EDT
# 2                                  12:23a EDT
# 3                                  12:27a EDT
# 4                                  12:33a EDT
# 5                                  12:43a EDT
# 6                                  01:03a EDT
# 7                                  01:08a EDT
# 8                                  01:08a EDT
# 9                                  01:10a EDT
# 10                                 01:14a EDT
# 11                                 01:20a EDT
# 12                                 01:32a EDT
# 13                                 01:36a EDT
# 14                                 01:36a EDT
# 15                                 02:14a EDT
# 16                                 02:35a EDT
# 17                                 02:40a EDT
# 18                                 02:48a EDT
# 19                                 02:51a EDT
#
#    (Scheduled Departures (More), Ident) (Scheduled Departures (More), Type)  \
# 0                               DLH8163                                B77L
# 1                               QFA7550                                B748
# 2                                 CPA95                                B744
# 3                               LAN2381                                B763
# 4                                DAL156                                B763
# 5                               JBU2103                                A320
# 6                                 THY12                                B77W
# 7                                AAL146                                B772
# 8                                AVA245                                A320
# 9                               AVA7393                                A319
# 10                              GLG7393                                A319
# 11                                EVA31                                B77W
# 12                               BWA527                                B38M
# 13                               PAL127                                A359
# 14                               AMX401                                B38M
# 15                               CMP807                                B738
# 16                              DAL2796                                B738
# 17                              CCA1078                                B77F
# 18                               TAI571                                A320
# 19                               AVA571                                A320
#
#      (Scheduled Departures (More), To)  (Scheduled Departures (More), Depart)  \
# 0                Frankfurt Int'l (FRA)                             10:36p EDT
# 1            Chicago O'Hare Intl (ORD)                             10:40p EDT
# 2                  Calgary Int'l (YYC)                             11:15p EDT
# 3             Jorge Chávez Int'l (LIM)                             11:25p EDT
# 4                   Kotoka Int'l (ACC)                             12:11a EDT
# 5          Luis Munoz Marin Intl (SJU)                             12:14a EDT
# 6               Istanbul Airport (IST)                             12:20a EDT
# 7               Ben Gurion Int'l (TLV)                             12:25a EDT
# 8                El Dorado Int'l (BOG)                             12:52a EDT
# 9   Jose Joaquin de Olmedo Int'l (GYE)                             01:15a EDT
# 10  Jose Joaquin de Olmedo Int'l (GYE)                             01:27a EDT
# 11          Taiwan Taoyuan Int'l (TPE)                             01:35a EDT
# 12            Cheddi Jagan Int'l (GEO)                             01:40a EDT
# 13               Vancouver Int'l (YVR)                             01:45a EDT
# 14      Lic. Benito Juarez Int'l (MEX)                             02:05a EDT
# 15                 Tocumen Int'l (PTY)                             02:25a EDT
# 16                     LaGuardia (LGA)                             02:39a EDT
# 17         Shanghai Pudong Int'l (PVG)                             03:25a EDT
# 18             El Salvador Int'l (SAL)                             03:50a EDT
# 19             El Salvador Int'l (SAL)                             03:50a EDT
#
#    (Scheduled Departures (More), Unnamed: 4_level_1)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# 7                                                NaN
# 8                                                NaN
# 9                                                NaN
# 10                                               NaN
# 11                                               NaN
# 12                                               NaN
# 13                                               NaN
# 14                                               NaN
# 15                                               NaN
# 16                                               NaN
# 17                                               NaN
# 18                                               NaN
# 19                                               NaN
#
#    (Scheduled Departures (More), Arrive)  \
# 0                            01:00p CEST
# 1                             12:15a CDT
# 2                             01:24a MDT
# 3                             05:50a -05
# 4                             01:50p GMT
# 5                             03:51a AST
# 6                             04:18p +03
# 7                             05:28p IDT
# 8                             05:00a -05
# 9                             06:26a -05
# 10                            06:33a -05
# 11                            05:14a CST
# 12                            07:00a -04
# 13                            04:10a PDT
# 14                            05:38a CDT
# 15                            06:38a EST
# 16                            02:41a EDT
# 17                            05:39a CST
# 18                            06:20a CST
# 19                            06:21a CST
#
#                                                     0
# 0   Your browser is unsupported. upgrade your browser
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
#
# [20 rows x 25 columns]

# %% [markdown]
# ## Data Cleaning

# %%
#data cleaned by remmoving unwanted columns from original data frame & creating a new df
jfk1 = jfk.drop(jfk.columns[[1,3,4,7,10,11,13,15,16,19,22,23,24]], axis=1)

#renaming the columns for ease of reading
jfk1.columns = ['ArrivalFlightNo', 'ArrivalFrom', 'ArrivalTime', 'DeptFlightNo', 'DeptTo', 'DeptTime', 'EnrouteFlightNo','EnrouteFrom','EnrouteArrivalTime','SchDeptFlightNo','SchDeptTo','SchDeptTime']
jfk1

#Cleaning df by filling NaN with NA
jfk1.fillna('NA')
# Out:
#    ArrivalFlightNo                      ArrivalFrom ArrivalTime DeptFlightNo  \
# 0          ICV5523        Chicago O'Hare Intl (ORD)  12:10a EDT         ELY8
# 1          JBU2492                 Miami Intl (MIA)  12:09a EDT       DAL234
# 2           DAL442        San Francisco Int'l (SFO)  12:07a EDT      JBU1523
# 3          DAL2245            Harry Reid Intl (LAS)  12:05a EDT       JBU745
# 4           DAL436           Los Angeles Intl (LAX)  12:00a EDT      RPA5836
# 5           CMP804              Tocumen Int'l (PTY)  12:00a EDT       ABX152
# 6          AAL2201           Los Angeles Intl (LAX)  12:00a EDT      LPE2381
# 7          ABX3162        San Bernardino Intl (SBD)  11:58p EDT       UAE202
# 8          JBU2126                 Tampa Intl (TPA)  11:56p EDT       JBU234
# 9           JBU284               Orlando Intl (MCO)  11:47p EDT      CAL5321
# 10         JBU1202       Fort Lauderdale Intl (FLL)  11:47p EDT       JBU553
# 11         DAL2238                 Miami Intl (MIA)  11:33p EDT       BAW182
# 12         AAL1357                 Miami Intl (MIA)  11:32p EDT       JBU553
# 13         JBU1882       Houston Bush Int'ctl (IAH)  11:31p EDT       VIR138
# 14         EDV5499   Minneapolis/St Paul Intl (MSP)  11:29p EDT        AFR17
# 15          DAL517    Hartsfield-Jackson Intl (ATL)  11:29p EDT      UPS1111
# 16          JBU342  Savannah/Hilton Head Intl (SAV)  11:26p EDT      GEC8163
# 17          JBU694      Austin-Bergstrom Intl (AUS)  11:22p EDT      FDX1612
# 18         JBU2928               Orlando Intl (MCO)  11:16p EDT       DAL471
# 19         ATN3332        Fort Worth Alliance (AFW)  11:15p EDT       JBU676
#
#                                                DeptTo    DeptTime  \
# 0                              Ben Gurion Int'l (TLV)  12:06a EDT
# 1                              Ben Gurion Int'l (TLV)  12:04a EDT
# 2                              Los Angeles Intl (LAX)  11:59p EDT
# 3                                     Mercedita (PSE)  11:44p EDT
# 4                             Boston Logan Intl (BOS)  11:33p EDT
# 5   Cincinnati/Northern Kentucky International Air...  11:31p EDT
# 6                            Jorge Chávez Int'l (LIM)  11:30p EDT
# 7                                   Dubai Int'l (DXB)  11:26p EDT
# 8                               Burlington Intl (BTV)  11:25p EDT
# 9                                Anchorage Intl (ANC)  11:24p EDT
# 10                                                 NA  11:23p EDT
# 11                              London Heathrow (LHR)  11:20p EDT
# 12                              Palm Beach Intl (PBI)  11:19p EDT
# 13                              London Heathrow (LHR)  11:17p EDT
# 14                     Charles de Gaulle/Roissy (CDG)  11:13p EDT
# 15                            Muhammad Ali Intl (SDF)  11:12p EDT
# 16                              Frankfurt Int'l (FRA)  11:11p EDT
# 17                            Indianapolis Intl (IND)  11:09p EDT
# 18                    São Paulo-Guarulhos Int'l (GRU)  11:07p EDT
# 19                               Worcester Rgnl (ORH)  11:06p EDT
#
#    EnrouteFlightNo                     EnrouteFrom EnrouteArrivalTime  \
# 0          DAL2463              Orlando Intl (MCO)         12:14a EDT
# 1           JBU504     Luis Munoz Marin Intl (SJU)         12:20a EDT
# 2           CMP832             Tocumen Int'l (PTY)         12:23a EDT
# 3           AMX404  Lic. Benito Juarez Int'l (MEX)         12:27a EDT
# 4           AAL634                Miami Intl (MIA)         12:33a EDT
# 5          JBU1730    Southwest Florida Intl (RSW)         12:43a EDT
# 6           DAL380       Salt Lake City Intl (SLC)         01:03a EDT
# 7          JBU1818              Piarco Int'l (POS)         01:08a EDT
# 8          JBU2124          Los Angeles Intl (LAX)         01:08a EDT
# 9           AVA570         El Salvador Int'l (SAL)         01:10a EDT
# 10         DAL2796               Denver Intl (DEN)         01:14a EDT
# 11          TAI570         El Salvador Int'l (SAL)         01:20a EDT
# 12          AAL293           London Heathrow (LHR)         01:32a EDT
# 13          TAI566         El Salvador Int'l (SAL)         01:36a EDT
# 14          AVA566         El Salvador Int'l (SAL)         01:36a EDT
# 15         JBU1760       Norman Manley Int'l (KIN)         02:14a EDT
# 16          JBU410              Las Americas (SDQ)         02:35a EDT
# 17         ITY9493            Malpensa Int'l (MXP)         02:40a EDT
# 18          CMP808             Tocumen Int'l (PTY)         02:48a EDT
# 19           AVA64        Rafael Nunez Int'l (CTG)         02:51a EDT
#
#    SchDeptFlightNo                           SchDeptTo SchDeptTime
# 0          DLH8163               Frankfurt Int'l (FRA)  10:36p EDT
# 1          QFA7550           Chicago O'Hare Intl (ORD)  10:40p EDT
# 2            CPA95                 Calgary Int'l (YYC)  11:15p EDT
# 3          LAN2381            Jorge Chávez Int'l (LIM)  11:25p EDT
# 4           DAL156                  Kotoka Int'l (ACC)  12:11a EDT
# 5          JBU2103         Luis Munoz Marin Intl (SJU)  12:14a EDT
# 6            THY12              Istanbul Airport (IST)  12:20a EDT
# 7           AAL146              Ben Gurion Int'l (TLV)  12:25a EDT
# 8           AVA245               El Dorado Int'l (BOG)  12:52a EDT
# 9          AVA7393  Jose Joaquin de Olmedo Int'l (GYE)  01:15a EDT
# 10         GLG7393  Jose Joaquin de Olmedo Int'l (GYE)  01:27a EDT
# 11           EVA31          Taiwan Taoyuan Int'l (TPE)  01:35a EDT
# 12          BWA527            Cheddi Jagan Int'l (GEO)  01:40a EDT
# 13          PAL127               Vancouver Int'l (YVR)  01:45a EDT
# 14          AMX401      Lic. Benito Juarez Int'l (MEX)  02:05a EDT
# 15          CMP807                 Tocumen Int'l (PTY)  02:25a EDT
# 16         DAL2796                     LaGuardia (LGA)  02:39a EDT
# 17         CCA1078         Shanghai Pudong Int'l (PVG)  03:25a EDT
# 18          TAI571             El Salvador Int'l (SAL)  03:50a EDT
# 19          AVA571             El Salvador Int'l (SAL)  03:50a EDT

# %% [markdown]
# ## Data analysis

# %% [markdown]
# ### 1. Flights on ground

# %%
# No of aircrafts on ground for the 1hour window
# No of flights arrived in last 30mins which have not departed yet and not scheduled to depart for the next 30mins minus No of flights departed in last 30mins
AircraftsOnGround = pd.concat([jfk1['ArrivalFlightNo'], jfk1['SchDeptFlightNo'], jfk1['EnrouteFlightNo']]).nunique() - len(jfk1['DeptFlightNo'])
AircraftsOnGround
# Out:
# 39

# %% [markdown]
# ### 2. Destination fight details

# %%
#taking input from the user to find out the flight details to their requested destination
print("Where would you like to go?")
inp = input()

#drops NA valued element in column and returns required details
jfk1[['SchDeptFlightNo','SchDeptTo','SchDeptTime']][jfk1.SchDeptTo.notnull()][jfk1.SchDeptTo.dropna().str.contains(inp)]
# Out:
# Where would you like to go?
# FCO
#   SchDeptFlightNo                                          SchDeptTo  \
# 1          ITY611    Leonardo da Vinci Int'l (Fiumicino Int'l) (FCO)
# 4          AZA611  Leonardo da Vinci Int'l (Fiumicino Int'l) (FCO...
#
#   SchDeptTime
# 1  09:40p EDT
# 4  09:50p EDT

# %% [markdown]
# ### 3. Arrival or Enroute flight details

# %%
#for people waiting to pick up a person at arrival gate, taking flight number and suggesting if the flight has landed or about to land
#Then provide flight details 
print("Waiting at arrival gate, what's the arrival flight number?")
inp = input()
m = jfk1[['EnrouteFrom','EnrouteArrivalTime']][jfk1['EnrouteFlightNo'].str.contains(inp)]

#checking if flight arrived or enroute
if m.empty == True:
    print('Already arrived & details as below:')
    n = jfk1[['ArrivalFrom','ArrivalTime']][jfk1['ArrivalFlightNo'].str.contains(inp)]
    print(n)
else:
    print('Yet to arrive & details as below:')
    print(m)
# Out:
# Waiting at arrival gate, what's the arrival flight number?
# JBU576
# Already arrived & details as below:
#                ArrivalFrom ArrivalTime
# 14  New Orleans Intl (MSY)  09:27p EDT

# %% [markdown]
# ### 4. Frequency distribution plot of arrived, enroute, departed and scheduled flights for one hour

# %%
#create subplots of 2x2 plots
fig, axs = plt.subplots(2, 2, sharey=True)

#counts of flights in each category
x1 = jfk1.ArrivalTime.value_counts()
x2 = jfk1.DeptTime.value_counts()
x3 = jfk1.EnrouteArrivalTime.value_counts()
x4 = jfk1.SchDeptTime.value_counts()
y = [1,2,3,4]

#plot frequency 
axs[0, 0].plot(x1)
axs[0, 0].set_title('Arrival')
axs[0, 1].plot(x2, 'tab:orange')
axs[0, 1].set_title('Departure')
axs[1, 0].plot(x3, 'tab:green')
axs[1, 0].set_title('EnRoute')
axs[1, 1].plot(x4, 'tab:red')
axs[1, 1].set_title('Scheduled Departure')

#rotate x axis ticks for better readability
for tick in axs[1,0].get_xticklabels():
    tick.set_rotation(90)
for tick in axs[1,1].get_xticklabels():
    tick.set_rotation(90)

# Hide x labels and tick labels for top plots and y ticks for right plots.
for ax in axs.flat:
    ax.label_outer()

fig.suptitle('Frequency of flights')
plt.show()
#plt.savefig('Arrival Frequency.png')

import warnings
warnings.filterwarnings("ignore")
